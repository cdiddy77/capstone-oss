# %%
import os
from dotenv import load_dotenv
load_dotenv()
from github import Github
from github import Auth


auth = Auth.Token(os.getenv("GITHUB_TOKEN",''))
g = Github(auth=auth)

# %%
import json

# Load the file
with open('trello.json', 'r') as file:
    data = json.load(file)

# Print the loaded data
print(data)
# Out:
# {'id': '62dab815c4e7796d16beaf9c', 'nodeId': 'ari:cloud:trello::board/workspace/612e4b9a9b6ba974c3c6c09e/62dab815c4e7796d16beaf9c', 'name': 'sidelineHD apps', 'desc': "Use this simple Kanban template to keep the engineering team on the same page and moving through work fluidly. \n\n1. Break down the roadmap by adding tasks as cards to the **Backlog** list. \n\n2. Move the cards one-by-one through **Design** as they becomes more fleshed out. *Pro tip:* You can enable Power-ups for your favorite design tools like [Figma](https://trello.com/power-ups/59b2e7611e6ece0b35eac16a/figma) or [Invision](https://trello.com/power-ups/596f2cb2d279152540b2bb31), in order to easily link and view designs without switching context.\n\n3. When a card is fully specced out and designs are attached, move it to **To Do** for engineers to pick up. \n\n4. Engineers move cards to **Doing** and assign themselves to the cards, so the whole team stays informed of who is working on what.\n\n5. Cards then move through **Code Review** when they're ready for a second set of eyes. The team can set a **List Limit** (with the List Limit Power-up) on the number of cards in Code Review, as a visual indicator for when the team needs to prioritize reviews rather than picking up new work. \n\n6. Once cards move through **Testing** and eventually ship to production, move them to **Done** and celebrate!\n", 'descData': None, 'closed': False, 'dateClosed': None, 'idOrganization': '612e4b9a9b6ba974c3c6c09e', 'idEnterprise': None, 'limits': {'attachments': {'perBoard': {'status': 'ok', 'disableAt': 36000, 'warnAt': 28800}, 'perCard': {'status': 'ok', 'disableAt': 1000, 'warnAt': 800}}, 'boards': {'totalMembersPerBoard': {'status': 'ok', 'disableAt': 1600, 'warnAt': 1280}, 'totalAccessRequestsPerBoard': {'status': 'ok', 'disableAt': 4000, 'warnAt': 3200}}, 'cards': {'openPerBoard': {'status': 'ok', 'disableAt': 5000, 'warnAt': 4000}, 'openPerList': {'status': 'ok', 'disableAt': 5000, 'warnAt': 4000}, 'totalPerBoard': {'status': 'ok', 'disableAt': 2000000, 'warnAt': 1600000}, 'totalPerList': {'status': 'ok', 'disableAt': 1000000, 'warnAt': 800000}}, 'checklists': {'perBoard': {'status': 'ok', 'disableAt': 1800000, 'warnAt': 1440000}, 'perCard': {'status': 'ok', 'disableAt': 500, 'warnAt': 400}}, 'checkItems': {'perChecklist': {'status': 'ok', 'disableAt': 200, 'warnAt': 160}}, 'customFields': {'perBoard': {'status': 'ok', 'disableAt': 50, 'warnAt': 40}}, 'customFieldOptions': {'perField': {'status': 'ok', 'disableAt': 50, 'warnAt': 40}}, 'labels': {'perBoard': {'status': 'ok', 'disableAt': 1000, 'warnAt': 800}}, 'lists': {'openPerBoard': {'status': 'ok', 'disableAt': 500, 'warnAt': 400}, 'totalPerBoard': {'status': 'ok', 'disableAt': 3000, 'warnAt': 2400}}, 'stickers': {'perCard': {'status': 'ok', 'disableAt': 70, 'warnAt': 56}}, 'reactions': {'perAction': {'status': 'ok', 'disableAt': 900, 'warnAt': 720}, 'uniquePerAction': {'status': 'ok', 'disableAt': 17, 'warnAt': 14}}}, 'pinned': False, 'starred': False, 'url': 'https://trello.com/b/dE5aYdRB/sidelinehd-apps', 'prefs': {'permissionLevel': 'org', 'hideVotes': False, 'voting': 'disabled', 'comments': 'members', 'invitations': 'members', 'selfJoin': False, 'cardCovers': True, 'cardCounts': False, 'isTemplate': False, 'cardAging': 'regular', 'calendarFeedEnabled': False, 'hiddenPluginBoardButtons': [], 'switcherViews': [{'viewType': 'Board', 'enabled': True}, {'viewType': 'Table', 'enabled': True}, {'viewType': 'Calendar', 'enabled': False}, {'viewType': 'Dashboard', 'enabled': False}, {'viewType': 'Timeline', 'enabled': False}, {'viewType': 'Map', 'enabled': False}], 'background': '5dfa855f31b76a80318febaf', 'backgroundColor': None, 'backgroundImage': 'https://trello-backgrounds.s3.amazonaws.com/SharedBackground/original/d71b9370b4cba91634ae4ffe331fb59a/photo-1576502200916-3808e07386a5', 'backgroundTile': False, 'backgroundBrightness': 'light', 'backgroundImageScaled': [{'width': 140, 'height': 94, 'url': 'https://trello-b ...

# %%
import webcolors
destination_repo = g.get_repo("diamondkinetics/sbot")

# Iterate over each label in the data.labels array
for label_entry in data['labels']:
    # Get the name of the label
    label_name = label_entry['name']
    print(f'creating [{label_name}] with color {label_entry["color"]}')

    # Check if the label already exists
    try:
        existing_label = destination_repo.get_label(name=label_name)
        if existing_label:
            print(f"The label '{label_name}' already exists in the repository.")
            continue
    except Exception as e:
        print(f"The label '{label_name}' does not exist in the repository.")

    # Get the color of the label
    label_color = label_entry['color']
    label_color = label_color.split('_')[0]
    # Convert the English color name to a hexadecimal string
    try:
        hex_color = webcolors.name_to_hex(label_color)
    except Exception as e:
        print(f"Error converting color '{label_color}' to hexadecimal. Using 'white' as the color.")
        hex_color = webcolors.name_to_hex("red")

    # Remove the '#' character from the hexadecimal string
    hex_color = hex_color[1:]

    # Print the hexadecimal color string
    print(hex_color)
    
    # Create the label in the GitHub repository with the specified name and color
    destination_repo.create_label(name=label_name, color=hex_color)
# Out:
# creating [app] with color orange
# The label 'app' already exists in the repository.
# creating [minor] with color orange
# The label 'minor' already exists in the repository.
# creating [feature / improvement] with color green
# The label 'feature / improvement' already exists in the repository.
# creating [major] with color red
# The label 'major' already exists in the repository.
# creating [sidelineREELS] with color pink_dark
# The label 'sidelineREELS' already exists in the repository.
# creating [playlist] with color pink_dark
# The label 'playlist' already exists in the repository.
# creating [livestreamer re-design] with color sky_dark
# The label 'livestreamer re-design' already exists in the repository.
# creating [generic scoring] with color yellow
# The label 'generic scoring' already exists in the repository.
# creating [blocker] with color red
# The label 'blocker' already exists in the repository.
# creating [needs repro] with color black_light
# The label 'needs repro' does not exist in the repository.
# 000000
# creating [sportsrecruits] with color orange_dark
# The label 'sportsrecruits' does not exist in the repository.
# ffa500
# creating [needs design] with color green_light
# The label 'needs design' does not exist in the repository.
# 008000
# creating [metrics] with color purple
# The label 'metrics' does not exist in the repository.
# 800080
# creating [growth] with color blue
# The label 'growth' does not exist in the repository.
# 0000ff
# creating [BB/SB Specific] with color lime_dark
# The label 'BB/SB Specific' does not exist in the repository.
# 00ff00
# creating [needs repro] with color blue_light
# The label 'needs repro' already exists in the repository.
# creating [app-launch-blocker] with color green_dark
# The label 'app-launch-blocker' does not exist in the repository.
# 008000
# creating [team settings] with color orange_light
# The label 'team settings' does not exist in the repository.
# ffa500
# creating [claim rate] with color sky
# The label 'claim rate' does not exist in the repository.
# Error converting color 'sky' to hexadecimal. Using 'white' as the color.
# ff0000
# creating [weekend issue] with color yellow_dark
# The label 'weekend issue' does not exist in the repository.
# ffff00
# creating [team page] with color blue_dark
# The label 'team page' does not exist in the repository.
# 0000ff
# creating [bug/defect] with color black
# The label 'bug/defect' does not exist in the repository.
# 000000
# creating [ios-only] with color lime
# The label 'ios-only' does not exist in the repository.
# 00ff00
# creating [partnerships] with color purple_light
# The label 'partnerships' does not exist in the repository.
# 800080
# creating [DK] with color lime_dark
# The label 'DK' does not exist in the repository.
# 00ff00
# creating [android-only] with color pink
# The label 'android-only' does not exist in the repository.
# ffc0cb
# creating [go live] with color purple_dark
# The label 'go live' does not exist in the repository.
# 800080

# %%
import webcolors
destination_repo = g.get_repo("diamondkinetics/sbot")

# Iterate over each entry in lists
for entry in data['lists']:
    # Get the name of the list
    list_name = entry['name']
    
    # Create the label name
    label_name = 'list:' + list_name
    
    # Check if the label already exists
    try:
        existing_label = destination_repo.get_label(name=label_name)
        if existing_label:
            print(f"The label '{label_name}' already exists in the repository.")
            continue
    except Exception as e:
        print(f"The label '{label_name}' does not exist in the repository.")
    
    print(f'creating [{label_name}]')
    # Create the label in the GitHub repository with the specified name and color
    destination_repo.create_label(name=label_name, color='ffffff')
# Out:
# The label 'list:Backlog' does not exist in the repository.
# creating [list:Backlog]
# The label 'list:Design' does not exist in the repository.
# creating [list:Design]
# The label 'list:To Do' does not exist in the repository.
# creating [list:To Do]
# The label 'list:Doing' does not exist in the repository.
# creating [list:Doing]
# The label 'list:Code Review' does not exist in the repository.
# creating [list:Code Review]
# The label 'list:Testing' does not exist in the repository.
# creating [list:Testing]
# The label 'list:Done' does not exist in the repository.
# creating [list:Done]
# The label 'list:Done [WEEK 3/6-12]' does not exist in the repository.
# creating [list:Done [WEEK 3/6-12]]
# The label 'list:Done' already exists in the repository.
# The label 'list:Done 🎉' does not exist in the repository.
# creating [list:Done 🎉]
# The label 'list:Deferred' does not exist in the repository.
# creating [list:Deferred]
# The label 'list:Obsolete' does not exist in the repository.
# creating [list:Obsolete]

# %%
for card in data['cards'][152:]:
    # Get the title and description from the card
    title = card['name']
    description = card['desc']
    
    # Create the issue in the destination repository
    new_issue = destination_repo.create_issue(title=title, body=description)
    print(f'created issue {new_issue.number} with title {title}')
    # Add labels to the new issue
    for label_entry in card['labels']:
        label_name = label_entry['name']
        
        # Check if the label already exists in the destination repository
        try:
            existing_label = destination_repo.get_label(name=label_name)
            if existing_label:
                new_issue.add_to_labels(existing_label)
        except Exception as e:
            print(f"The label '{label_name}' does not exist in the repository.")

    # Get the idList of the card
    idList = card['idList']
    
    # Find the matching list in data['lists']
    matching_list = next((lst for lst in data['lists'] if lst['id'] == idList), None)
    
    # If a matching list is found, add the label to the card
    if matching_list:
        list_name = matching_list['name']
        label_name = 'list:' + list_name
        # Add the label to the card
        # (Replace this line with the actual code to add the label to the card)
        try:
            existing_label = destination_repo.get_label(name=label_name)
            if existing_label:
                print(f"Adding label '{label_name}' to card '{card['name']}'")
                new_issue.add_to_labels(existing_label)
        except Exception as e:
            print(f"The label '{label_name}' does not exist in the repository.")
    else:
        print(f"No matching list found for card '{card['name']}'")
# Out:
# created issue 831 with title Possible PG import bug
# Adding label 'list:Backlog' to card 'Possible PG import bug'
# created issue 832 with title Limits on claiming players is not working properly
# Adding label 'list:Backlog' to card 'Limits on claiming players is not working properly'
# created issue 833 with title Team player clips on player page should be locked in some way
# Adding label 'list:Backlog' to card 'Team player clips on player page should be locked in some way'
# created issue 834 with title Schedule emails to collect optional claimed player fields
# Adding label 'list:Backlog' to card 'Schedule emails to collect optional claimed player fields'
# created issue 835 with title mobx array out of bounds warning
# Adding label 'list:Backlog' to card 'mobx array out of bounds warning'
# created issue 836 with title Generic scoreboard position indicator is off
# Adding label 'list:Backlog' to card 'Generic scoreboard position indicator is off'
# created issue 837 with title Away/Home is flipped in generic scoring
# Adding label 'list:Backlog' to card 'Away/Home is flipped in generic scoring'
# created issue 838 with title Generic (or just basketball) timeout button
# Adding label 'list:Backlog' to card 'Generic (or just basketball) timeout button'
# created issue 839 with title Basketball scoring: change who took the shot to include two sections, most recent and all others
# Adding label 'list:Backlog' to card 'Basketball scoring: change who took the shot to include two sections, most recent and all others'
# created issue 840 with title Highlight Videos missing in metabase
# Adding label 'list:Backlog' to card 'Highlight Videos missing in metabase'
# created issue 841 with title Simplify claim player page
# Adding label 'list:Backlog' to card 'Simplify claim player page'
# created issue 842 with title When impersonating, changing the capture setup on the user account resulted in it being renamed to the impersonator's name
# Adding label 'list:Backlog' to card 'When impersonating, changing the capture setup on the user account resulted in it being renamed to the impersonator's name'
# created issue 843 with title Fix "externalSource" for imported teams.
# Adding label 'list:Backlog' to card 'Fix "externalSource" for imported teams.'
# created issue 844 with title add mixpanel tracking for onboarding events
# Adding label 'list:Backlog' to card 'add mixpanel tracking for onboarding events'
# created issue 845 with title enable safari app install banner
# Adding label 'list:Backlog' to card 'enable safari app install banner'
# created issue 846 with title show strong visual indicator of impersonation
# Adding label 'list:Backlog' to card 'show strong visual indicator of impersonation'
# created issue 847 with title setup basic notifications plumbing
# Adding label 'list:Backlog' to card 'setup basic notifications plumbing'
# created issue 848 with title zoom ratio < 1 ?
# Adding label 'list:Backlog' to card 'zoom ratio < 1 ?'
# created issue 849 with title feature: dim screen after awhile when streaming
# Adding label 'list:Backlog' to card 'feature: dim screen after awhile when streaming'
# created issue 850 with title splash screen
# Adding label 'list:Backlog' to card 'splash screen'
# created issue 851 with title Look into c2.sidelineHD.com text link tracking issue
# Adding label 'list:Backlog' to card 'Look into c2.sidelineHD.com text link tracking issue'
# created issue 852 with title weird textinput focus issue when switching between settings and camera
# Adding label 'list:Backlog' to card 'weird textinput focus issue when switching between settings and camera'
# created issue 853 with title iScore player discovery - improve name matching intelligence
# Adding label 'list:Backlog' to card 'iScore player discovery - improve name matching intelligence'
# created issue 854 with title make so camera isnt burning battery while camera screen isnt up
# Adding label 'list:Backlog' to card 'make so camera isnt burning battery while camera screen isnt up'
# created issue 855 with title add option to turn on low-level logging from native video engine
# Adding label 'list:Backlog' to card 'add option to turn on low-level logging from native video engine'
# created issue 856 with title send app notifications in addition to/instead of text notifications
# Adding label 'list:Backlog' to card 'send app notifications in addition to/instead of text notifications'
# created issue 857 with title Missing age level/team type/age data in team docs (metabase)
# Adding label 'list:Backlog' to card 'Missing age level/team type/age data in team docs (metabase)'
# created issue 858 with title remove shuffle from viewer mode
# Adding label 'list:Backlog' to card 'remove shuffle from viewer mode'
# created issue 859 with title Investigate Retool for internal tools
# Adding label 'list:Backlog' to card 'Investigate Retool for internal tools'
# created issue 860 with title scheduled game showing as live
# Adding label 'list:Backlog' to card 'scheduled game showing as live'
# created issue 861 with title clips missing from sidelineREELS
# Adding label 'list:Backlog' to card 'clips missing from sidelineREELS'
# created issue 862 with title preview not working for some clips on mobile
# Adding label 'list:Backlog' to card 'preview not working for some clips on mobile'
# created issue 863 with title redesign import options step in livestreamer onboarding
# Adding label 'list:Backlog' to card 'redesign import options step in livestreamer onboarding'
# created issue 864 with title Undefined / unknown behavior for a user who has started onboarding but then gets invited as a coach
# Adding label 'list:Backlog' to card 'Undefined / unknown behavior for a user who has started onboarding but then gets invited as a coach'
# created issue 865 with title Allow users to re-use last title when creating a game
# Adding label 'list:Backlog' to card 'Allow users to re-use last title when creating a game'
# created issue 866 with title New users don't have "setup advanced camera" button in go live card
# Adding label 'list:Backlog' to card 'New users don't have "setup advanced camera" button in go live card'
# created issue 867 with title add ability to nag for update
# Adding label 'list:Backlog' to card 'add ability to nag for update'
# created issue 868 with title enable uploading video recording to sidelineHD afterward
# Adding label 'list:Backlog' to card 'enable uploading video recording to sidelineHD afterward'
# created issue 869 with title Stop streaming button not working if trying to connect to an invalid RTMP url
# Adding label 'list:Backlog' to card 'Stop streaming button not working if trying to connect to an invalid RTMP url'
# created issue 870 with title Bug where camera somehow ends up sending portrait mode feed
# Adding label 'list:Backlog' to card 'Bug where camera somehow ends up sending portrait mode feed'
# created issue 871 with title address apple app review warning
# Adding label 'list:Backlog' to card 'address apple app review warning'
# created issue 872 with title alerts for SR linking
# Adding label 'list:Backlog' to card 'alerts for SR linking'
# created issue 873 with title delete manager invite cancel button not working
# Adding label 'list:Backlog' to card 'delete manager invite cancel button not working'
# created issue 874 with title game page time rendering wrong
# Adding label 'list:Backlog' to card 'game page time rendering wrong'
# created issue 875 with title cannot change team type
# Adding label 'list:Backlog' to card 'cannot change team type'
# created issue 876 with title /app/golive/team/<teamid> should open the app and it doesnt
# Adding label 'list:Backlog' to card '/app/golive/team/<teamid> should open the app and it doesnt'
# created issue 877 with title player DK icon shows on non-bbsb team profiles
# Adding label 'list:Backlog' to card 'player DK icon shows on non-bbsb team profiles'
# created issue 878 with title Import from PG for softball
# Adding label 'list:Backlog' to card 'Import from PG for softball'
# created issue 879 with title handle case where a different capture device/doc is streaming the team and user tries to go live:
# Adding label 'list:Backlog' to card 'handle case where a different capture device/doc is streaming the team and user tries to go live:'
# created issue 880 with title make so streamboard can show whether the app stream is android or ios
# Adding label 'list:Backlog' to card 'make so streamboard can show whether the app stream is android or ios'
# created issue 881 with title SportsRecruits issue
# Adding label 'list:Backlog' to card 'SportsRecruits issue'
# created issue 882 with title android photo upload fix
# Adding label 'list:Backlog' to card 'android photo upload fix'
# created issue 883 with title test whether the app works with google meet at the same time.
# Adding label 'list:Backlog' to card 'test whether the app works with google meet at the same time.'
# created issue 884 with title allow specifying audio input source (back/front/bottom)
# Adding label 'list:Backlog' to card 'allow specifying audio input source (back/front/bottom)'
# created issue 885 with title More internal tools
# Adding label 'list:Backlog' to card 'More internal tools'
# created issue 886 with title Design & Research
# Adding label 'list:Design' to card 'Design & Research'
# created issue 887 with title [Example task with designs]
# Adding label 'list:Design' to card '[Example task with designs]'
# created issue 888 with title To Do
# Adding label 'list:To Do' to card 'To Do'
# created issue 889 with title investigate vb tagging bug
# Adding label 'list:To Do' to card 'investigate vb tagging bug'
# created issue 890 with title College commitment list should not allow multi-select...
# Adding label 'list:To Do' to card 'College commitment list should not allow multi-select...'
# created issue 891 with title Enable UID-based referral code
# Adding label 'list:To Do' to card 'Enable UID-based referral code'
# created issue 892 with title Don't show extra period on game page
# Adding label 'list:To Do' to card 'Don't show extra period on game page'
# created issue 893 with title weekly clips email for VB parents
# Adding label 'list:To Do' to card 'weekly clips email for VB parents'
# created issue 894 with title [INVESTIGATE] claim flow seems broken
# Adding label 'list:To Do' to card '[INVESTIGATE] claim flow seems broken'
# created issue 895 with title Duplicate game state to clipEvent
# Adding label 'list:To Do' to card 'Duplicate game state to clipEvent'
# created issue 896 with title Sharing a clip without tagged players from a game page results in a broken link
# Adding label 'list:To Do' to card 'Sharing a clip without tagged players from a game page results in a broken link'
# created issue 897 with title Team staff management
# Adding label 'list:To Do' to card 'Team staff management'
# created issue 898 with title Games tab improvements
# Adding label 'list:To Do' to card 'Games tab improvements'
# created issue 899 with title Team Information page UI refresh
# Adding label 'list:To Do' to card 'Team Information page UI refresh'
# created issue 900 with title Sponsor Logos page UI refresh
# Adding label 'list:To Do' to card 'Sponsor Logos page UI refresh'
# created issue 901 with title Privacy page UI refresh
# Adding label 'list:To Do' to card 'Privacy page UI refresh'
# created issue 902 with title Stream Publishing page
# Adding label 'list:To Do' to card 'Stream Publishing page'
# created issue 903 with title Camera Settings UI refresh
# Adding label 'list:To Do' to card 'Camera Settings UI refresh'
# created issue 904 with title Live Pitch Velo UI refresh
# Adding label 'list:To Do' to card 'Live Pitch Velo UI refresh'
# created issue 905 with title Add team cover photo to database
# Adding label 'list:To Do' to card 'Add team cover photo to database'
# created issue 906 with title Game scheduled start time is 0 sometimes
# Adding label 'list:To Do' to card 'Game scheduled start time is 0 sometimes'
# created issue 907 with title Investigate how userDoc.phoneList got more than one entry in it
# Adding label 'list:To Do' to card 'Investigate how userDoc.phoneList got more than one entry in it'
# created issue 908 with title add a read-only setting for app version
# Adding label 'list:To Do' to card 'add a read-only setting for app version'
# created issue 909 with title Doing
# Adding label 'list:Doing' to card 'Doing'
# created issue 910 with title Generate aggregate stats based on all game states
# Adding label 'list:Doing' to card 'Generate aggregate stats based on all game states'
# created issue 911 with title Capture names for Apple users who sign up to claim a player
# Adding label 'list:Doing' to card 'Capture names for Apple users who sign up to claim a player'
# created issue 912 with title Go Live flow
# Adding label 'list:Doing' to card 'Go Live flow'
# created issue 913 with title Logged out Team page
# Adding label 'list:Doing' to card 'Logged out Team page'
# created issue 914 with title Fix end of clip state
# Adding label 'list:Doing' to card 'Fix end of clip state'
# created issue 915 with title Need to actually get athlete email in SR modal
# Adding label 'list:Doing' to card 'Need to actually get athlete email in SR modal'
# created issue 916 with title [Example task]
# Adding label 'list:Doing' to card '[Example task]'
# created issue 917 with title Add routing to tabs on the team page
# Adding label 'list:Doing' to card 'Add routing to tabs on the team page'
# created issue 918 with title Pull WOW teams from LA
# Adding label 'list:Doing' to card 'Pull WOW teams from LA'
# created issue 919 with title box score feedback button in the way
# Adding label 'list:Doing' to card 'box score feedback button in the way'
# created issue 920 with title Code Review
# Adding label 'list:Code Review' to card 'Code Review'
# created issue 921 with title This list has the List Limits Power-up enabled, to help the team prioritize and remove bottlenecks before picking up new work. The list will be highlighted if the number of cards in it passes the limit that the team determines based on team size.
# Adding label 'list:Code Review' to card 'This list has the List Limits Power-up enabled, to help the team prioritize and remove bottlenecks before picking up new work. The list will be highlighted if the number of cards in it passes the limit that the team determines based on team size.'
# created issue 922 with title [Example task]
# Adding label 'list:Code Review' to card '[Example task]'
# created issue 923 with title [Example task]
# Adding label 'list:Code Review' to card '[Example task]'
# created issue 924 with title Testing
# Adding label 'list:Testing' to card 'Testing'
# created issue 925 with title Roster
# Adding label 'list:Testing' to card 'Roster'
# created issue 926 with title "Team is live" card
# Adding label 'list:Testing' to card '"Team is live" card'
# created issue 927 with title Make all of the team settings pages use selectedTeam from mobx store
# Adding label 'list:Testing' to card 'Make all of the team settings pages use selectedTeam from mobx store'
# created issue 928 with title User settings side modal
# Adding label 'list:Testing' to card 'User settings side modal'
# created issue 929 with title new player tagging interface
# Adding label 'list:Testing' to card 'new player tagging interface'
# created issue 930 with title Facebook / YouTube destination buttons
# Adding label 'list:Testing' to card 'Facebook / YouTube destination buttons'
# created issue 931 with title better photo uploading component / UI
# Adding label 'list:Testing' to card 'better photo uploading component / UI'
# created issue 932 with title home page functionality
# Adding label 'list:Testing' to card 'home page functionality'
# created issue 933 with title new home screen scaffolding
# Adding label 'list:Testing' to card 'new home screen scaffolding'
# created issue 934 with title team page tabs scaffolding
# Adding label 'list:Testing' to card 'team page tabs scaffolding'
# created issue 935 with title Settings hierarchy / navigation / routing scaffolding
# Adding label 'list:Testing' to card 'Settings hierarchy / navigation / routing scaffolding'
# created issue 936 with title Incremental "launch" of new livestreamer UX that uses remote config
# Adding label 'list:Testing' to card 'Incremental "launch" of new livestreamer UX that uses remote config'
# created issue 937 with title New ADD GROUP page
# Adding label 'list:Testing' to card 'New ADD GROUP page'
# created issue 938 with title clip trimming not accurate
# Adding label 'list:Testing' to card 'clip trimming not accurate'
# created issue 939 with title Remove pronouns from AI generated recaps
# Adding label 'list:Testing' to card 'Remove pronouns from AI generated recaps'
# created issue 940 with title VB scoring tour buttons are hidden by nav bar
# Adding label 'list:Testing' to card 'VB scoring tour buttons are hidden by nav bar'
# created issue 941 with title Bad loading state in Play-by-Play tab
# Adding label 'list:Testing' to card 'Bad loading state in Play-by-Play tab'
# created issue 942 with title sidelineREELS: download button
# Adding label 'list:Testing' to card 'sidelineREELS: download button'
# created issue 943 with title backend user role validation
# Adding label 'list:Testing' to card 'backend user role validation'
# created issue 944 with title Fix sharing from ReelsList
# Adding label 'list:Testing' to card 'Fix sharing from ReelsList'
# created issue 945 with title make sure to ask for photos permissions when the user selects to save recordings to photos.
# Adding label 'list:Testing' to card 'make sure to ask for photos permissions when the user selects to save recordings to photos.'
# created issue 946 with title make so can set a different dimension for recording.
# Adding label 'list:Testing' to card 'make so can set a different dimension for recording.'
# created issue 947 with title battery life indicator
# Adding label 'list:Testing' to card 'battery life indicator'
# created issue 948 with title Create android version
# Adding label 'list:Testing' to card 'Create android version'
# created issue 949 with title fix so the website link is better, not clipped ever, and maybe just call it website.
# Adding label 'list:Testing' to card 'fix so the website link is better, not clipped ever, and maybe just call it website.'
# created issue 950 with title put settings back on the hamburger menu
# Adding label 'list:Testing' to card 'put settings back on the hamburger menu'
# created issue 951 with title when there is an error saving to photos, settle for saving to local storage instead.
# Adding label 'list:Testing' to card 'when there is an error saving to photos, settle for saving to local storage instead.'
# created issue 952 with title Android support for exposure locking
# Adding label 'list:Testing' to card 'Android support for exposure locking'
# created issue 953 with title Detect when device does not support HEVC
# Adding label 'list:Testing' to card 'Detect when device does not support HEVC'
# created issue 954 with title Testing
# Adding label 'list:Done' to card 'Testing'
# created issue 955 with title Improve score / assist flow
# Adding label 'list:Done' to card 'Improve score / assist flow'
# created issue 956 with title Update LA import copy
# Adding label 'list:Done' to card 'Update LA import copy'
# created issue 957 with title Hockey goals not showing up in box score
# Adding label 'list:Done' to card 'Hockey goals not showing up in box score'
# created issue 958 with title VB clip page has a bad URL in it
# Adding label 'list:Done' to card 'VB clip page has a bad URL in it'
# created issue 959 with title New GoPro link
# Adding label 'list:Done' to card 'New GoPro link'
# created issue 960 with title Linking NPE Facebook pages
# Adding label 'list:Done' to card 'Linking NPE Facebook pages'
# created issue 961 with title Done
# Adding label 'list:Done' to card 'Done'
# created issue 962 with title get user's name when they sign up with apple
# Adding label 'list:Done' to card 'get user's name when they sign up with apple'
# created issue 963 with title Prevent admins from impersonating a deleted user
# Adding label 'list:Done' to card 'Prevent admins from impersonating a deleted user'
# created issue 964 with title new component library
# Adding label 'list:Done' to card 'new component library'
# created issue 965 with title update seasons list in onboarding
# Adding label 'list:Done' to card 'update seasons list in onboarding'
# created issue 966 with title Default date is UTC instead of local time on game creation
# Adding label 'list:Done' to card 'Default date is UTC instead of local time on game creation'
# created issue 967 with title Alignment issue at top of generic scoring app
# Adding label 'list:Done' to card 'Alignment issue at top of generic scoring app'
# created issue 968 with title Basic internal tools
# Adding label 'list:Done' to card 'Basic internal tools'
# created issue 969 with title Get BBSB game flow stats
# Adding label 'list:Done' to card 'Get BBSB game flow stats'
# created issue 970 with title Investigate FB graph API v19.0
# Adding label 'list:Done' to card 'Investigate FB graph API v19.0'
# created issue 971 with title New FB page linking blocker
# Adding label 'list:Done' to card 'New FB page linking blocker'
# created issue 972 with title Invalid SR link
# Adding label 'list:Done' to card 'Invalid SR link'
# created issue 973 with title AES import not sorting properly
# Adding label 'list:Done' to card 'AES import not sorting properly'
# created issue 974 with title stream status on player page shows up erroneously
# Adding label 'list:Done' to card 'stream status on player page shows up erroneously'
# created issue 975 with title auth issues when user tries to invite a player manager
# Adding label 'list:Done' to card 'auth issues when user tries to invite a player manager'
# created issue 976 with title tickets cannot be created via help desk widget
# Adding label 'list:Done' to card 'tickets cannot be created via help desk widget'
# created issue 977 with title Fix B/T in PG data
# Adding label 'list:Done' to card 'Fix B/T in PG data'
# created issue 978 with title "Fatal error" in generic scoring
# Adding label 'list:Done' to card '"Fatal error" in generic scoring'
# created issue 979 with title bbsb box score tweaks
# Adding label 'list:Done' to card 'bbsb box score tweaks'
# created issue 980 with title File bug to FB about "'create live_videos: Unsupported request - method type: post'"
# Adding label 'list:Done' to card 'File bug to FB about "'create live_videos: Unsupported request - method type: post'"'
# Request POST /repos/diamondkinetics/sbot/issues failed with 403: Forbidden
# Setting next backoff to 60s
# Request POST /repos/diamondkinetics/sbot/issues failed with 403: Forbidden
# Setting next backoff to 60s
# Request POST /repos/diamondkinetics/sbot/issues failed with 403: Forbidden
# Setting next backoff to 60s
# Request POST /repos/diamondkinetics/sbot/issues failed with 403: Forbidden
# Setting next backoff to 60s
# Request POST /repos/diamondkinetics/sbot/issues failed with 403: Forbidden
# Setting next backoff to 60s
# Request POST /repos/diamondkinetics/sbot/issues failed with 403: Forbidden
# Setting next backoff to 60s
# Request POST /repos/diamondkinetics/sbot/issues failed with 403: Forbidden
# Setting next backoff to 60s
# Request POST /repos/diamondkinetics/sbot/issues failed with 403: Forbidden
# Setting next backoff to 60s
# Request POST /repos/diamondkinetics/sbot/issues failed with 403: Forbidden
# Setting next backoff to 60s
# Request POST /repos/diamondkinetics/sbot/issues failed with 403: Forbidden
# Setting next backoff to 60s
# Request POST /repos/diamondkinetics/sbot/issues failed with 403: Forbidden
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# ResponseError: too many 403 error responses
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/dev/capstone-oss/venv/lib/python3.9/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~/dev/capstone-oss/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:945, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     944     log.debug("Retry: %s", url)
# --> 945     return self.urlopen(
#     946         method,
#     947         url,
#     948         body,
#     949         headers,
#     950         retries=retries,
#     951         redirect=redirect,
#     952         assert_same_host=assert_same_host,
#     953         timeout=timeout,
#     954         pool_timeout=pool_timeout,
#     955         release_conn=release_conn,
#     956         chunked=chunked,
#     957         body_pos=body_pos,
#     958         preload_content=preload_content,
#     959         decode_content=decode_content,
#     960         **response_kw,
#     961     )
#     963 return response
#
# File ~/dev/capstone-oss/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:945, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     944     log.debug("Retry: %s", url)
# --> 945     return self.urlopen(
#     946         method,
#     947         url,
#     948         body,
#     949         headers,
#     950         retries=retries,
#     951         redirect=redirect,
#     952         assert_same_host=assert_same_host,
#     953         timeout=timeout,
#     954         pool_timeout=pool_timeout,
#     955         release_conn=release_conn,
#     956         chunked=chunked,
#     957         body_pos=body_pos,
#     958         preload_content=preload_content,
#     959         decode_content=decode_content,
#     960         **response_kw,
#     961     )
#     963 return response
#
#     [... skipping similar frames: HTTPConnectionPool.urlopen at line 945 (7 times)]
#
# File ~/dev/capstone-oss/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:945, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     944     log.debug("Retry: %s", url)
# --> 945     return self.urlopen(
#     946         method,
#     947         url,
#     948         body,
#     949         headers,
#     950         retries=retries,
#     951         redirect=redirect,
#     952         assert_same_host=assert_same_host,
#     953         timeout=timeout,
#     954         pool_timeout=pool_timeout,
#     955         release_conn=release_conn,
#     956         chunked=chunked,
#     957         body_pos=body_pos,
#     958         preload_content=preload_content,
#     959         decode_content=decode_content,
#     960         **response_kw,
#     961     )
#     963 return response
#
# File ~/dev/capstone-oss/venv/lib/python3.9/site-packages/urllib3/connectionpool.py:935, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     934 try:
# --> 935     retries = retries.increment(method, url, response=response, _pool=self)
#     936 except MaxRetryError:
#
# File ~/dev/capstone-oss/venv/lib/python3.9/site-packages/github/GithubRetry.py:129, in GithubRetry.increment(self, method, url, response, error, _pool, _stacktrace)
#     128 # check early that we are retrying at all
# --> 129 retry = super().increment(method, url, response, error, _pool, _stacktrace)
#     131 # we backoff primary rate limit at least until X-RateLimit-Reset,
#     132 # we backoff secondary rate limit at for secondary_rate_wait seconds
#
# File ~/dev/capstone-oss/venv/lib/python3.9/site-packages/urllib3/util/retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /repos/diamondkinetics/sbot/issues (Caused by ResponseError('too many 403 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# RetryError                                Traceback (most recent call last)
# Cell In[24], line 7
#       4 description = card['desc']
#       6 # Create the issue in the destination repository
# ----> 7 new_issue = destination_repo.create_issue(title=title, body=description)
#       8 print(f'created issue {new_issue.number} with title {title}')
#       9 # Add labels to the new issue
#
# File ~/dev/capstone-oss/venv/lib/python3.9/site-packages/github/Repository.py:1389, in Repository.create_issue(self, title, body, assignee, milestone, labels, assignees)
#    1384 if is_defined(labels):
#    1385     post_parameters["labels"] = [
#    1386         element.name if isinstance(element, github.Label.Label) else element
#    1387         for element in labels  # type: ignore
#    1388     ]
# -> 1389 headers, data = self._requester.requestJsonAndCheck("POST", f"{self.url}/issues", input=post_parameters)
#    1390 return github.Issue.Issue(self._requester, headers, data, completed=True)
#
# File ~/dev/capstone-oss/venv/lib/python3.9/site-packages/github/Requester.py:494, in Requester.requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     486 def requestJsonAndCheck(
#     487     self,
#     488     verb: str,
#    (...)
#     492     input: Optional[Any] = None,
#     493 ) -> Tuple[Dict[str, Any], Any]:
# --> 494     return self.__check(*self.requestJson(verb, url, parameters, headers, input, self.__customConnection(url)))
#
# File ~/dev/capstone-oss/venv/lib/python3.9/site-packages/github/Requester.py:629, in Requester.requestJson(self, verb, url, parameters, headers, input, cnx)
#     626 def encode(input: Any) -> Tuple[str, str]:
#     627     return "application/json", json.dumps(input)
# --> 629 return self.__requestEncode(cnx, verb, url, parameters, headers, input, encode)
#
# File ~/dev/capstone-oss/venv/lib/python3.9/site-packages/github/Requester.py:726, in Requester.__requestEncode(self, cnx, verb, url, parameters, requestHeaders, input, encode)
#     722     requestHeaders["Content-Type"], encoded_input = encode(input)
#     724 self.NEW_DEBUG_FRAME(requestHeaders)
# --> 726 status, responseHeaders, output = self.__requestRaw(cnx, verb, url, requestHeaders, encoded_input)
#     728 if Consts.headerRateRemaining in responseHeaders and Consts.headerRateLimit in responseHeaders:
#     729     self.rate_limiting = (
#     730         # ints expected but sometimes floats returned: https://github.com/PyGithub/PyGithub/pull/2697
#     731         int(float(responseHeaders[Consts.headerRateRemaining])),
#     732         int(float(responseHeaders[Consts.headerRateLimit])),
#     733     )
#
# File ~/dev/capstone-oss/venv/lib/python3.9/site-packages/github/Requester.py:760, in Requester.__requestRaw(self, cnx, verb, url, requestHeaders, input)
#     758     cnx = self.__createConnection()
#     759 cnx.request(verb, url, input, requestHeaders)
# --> 760 response = cnx.getresponse()
#     762 status = response.status
#     763 responseHeaders = {k.lower(): v for k, v in response.getheaders()}
#
# File ~/dev/capstone-oss/venv/lib/python3.9/site-packages/github/Requester.py:174, in HTTPSRequestsConnectionClass.getresponse(self)
#     172 verb = getattr(self.session, self.verb.lower())
#     173 url = f"{self.protocol}://{self.host}:{self.port}{self.url}"
# --> 174 r = verb(
#     175     url,
#     176     headers=self.headers,
#     177     data=self.input,
#     178     timeout=self.timeout,
#     179     verify=self.verify,
#     180     allow_redirects=False,
#     181 )
#     182 return RequestsResponse(r)
#
# File ~/dev/capstone-oss/venv/lib/python3.9/site-packages/requests/sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)
#     634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~/dev/capstone-oss/venv/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/dev/capstone-oss/venv/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/dev/capstone-oss/venv/lib/python3.9/site-packages/requests/adapters.py:510, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     507         raise ConnectTimeout(e, request=request)
#     509 if isinstance(e.reason, ResponseError):
# --> 510     raise RetryError(e, request=request)
#     512 if isinstance(e.reason, _ProxyError):
#     513     raise ProxyError(e, request=request)
#
# RetryError: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /repos/diamondkinetics/sbot/issues (Caused by ResponseError('too many 403 error responses'))

# %%
card_name = 'File bug to FB about "\'create live_videos: Unsupported request - method type: post\'"'
card_index = None

for index, card in enumerate(data['cards']):
    if card['name'] == card_name:
        card_index = index
        break

print(f"The index of the first card with the name '{card_name}' is: {card_index}")
# Out:
# The index of the first card with the name 'File bug to FB about "'create live_videos: Unsupported request - method type: post'"' is: 301

# %% [markdown]
# ## add issue

# %%
# Specify the source and destination repositories
source_repo_name = "diamondkinetics/dk-product"
destination_repo_name = "diamondkinetics/sbot"


# Get the source and destination repositories
source_repo = g.get_repo(source_repo_name)
destination_repo = g.get_repo(destination_repo_name)

# Specify the issue number of the issue you want to move
issue_number_to_move = 1657  # Replace with the actual issue number

# Get the issue from the source repository
issue_to_move = source_repo.get_issue(issue_number_to_move)

# Create a new issue in the destination repository with the same title and body
new_issue = destination_repo.create_issue(
    title=issue_to_move.title,
    body=issue_to_move.body
)

# Close the original issue in the source repository
issue_to_move.edit(state="closed")

# Add a comment to the original issue indicating it has been moved
issue_to_move.create_comment(
    "This issue has been moved to {0}#{1}".format(destination_repo_name, new_issue.number)
)

print("Issue successfully moved from {0} to {1}".format(source_repo_name, destination_repo_name))
# Out:
# ---------------------------------------------------------------------------
# BadCredentialsException                   Traceback (most recent call last)
# Cell In[4], line 7
#       3 destination_repo_name = "diamondkinetics/sbot"
#       6 # Get the source and destination repositories
# ----> 7 source_repo = g.get_repo(source_repo_name)
#       8 destination_repo = g.get_repo(destination_repo_name)
#      10 # Specify the issue number of the issue you want to move
#
# File ~/dev/capstone-oss/venv/lib/python3.9/site-packages/github/MainClass.py:380, in Github.get_repo(self, full_name_or_id, lazy)
#     378 if lazy:
#     379     return github.Repository.Repository(self.__requester, {}, {"url": url}, completed=False)
# --> 380 headers, data = self.__requester.requestJsonAndCheck("GET", url)
#     381 return github.Repository.Repository(self.__requester, headers, data, completed=True)
#
# File ~/dev/capstone-oss/venv/lib/python3.9/site-packages/github/Requester.py:494, in Requester.requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     486 def requestJsonAndCheck(
#     487     self,
#     488     verb: str,
#    (...)
#     492     input: Optional[Any] = None,
#     493 ) -> Tuple[Dict[str, Any], Any]:
# --> 494     return self.__check(*self.requestJson(verb, url, parameters, headers, input, self.__customConnection(url)))
#
# File ~/dev/capstone-oss/venv/lib/python3.9/site-packages/github/Requester.py:525, in Requester.__check(self, status, responseHeaders, output)
#     523 data = self.__structuredFromJson(output)
#     524 if status >= 400:
# --> 525     raise self.createException(status, responseHeaders, data)
#     526 return responseHeaders, data
#
# BadCredentialsException: 401 {"message": "Bad credentials", "documentation_url": "https://docs.github.com/rest"}
